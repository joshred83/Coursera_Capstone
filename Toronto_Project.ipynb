# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
from pandas.io.json import json_normalize
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from pprint import pprint
import requests # library to handle requests
from bs4 import BeautifulSoup

# !conda install -c conda-forge folium --yes
import folium


from functools import lru_cache

# %% [markdown]
# # Start of question 1

# %% [markdown]
# ### Use requests & Beautiful soup to scrape the table

# %%
url ="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
r = requests.get(url)
soup = BeautifulSoup(r.content)

# %%
trs = soup.find_all('tr')
table = []
for ix, tr in enumerate(trs):
    tds = tr.find_all('td')
    table.append([tds[x].text.strip() for x, _ in enumerate(tds)])
    
data = table[1:288]
header= ['postcode', 'borough', 'neighbourhood']
postcode_df = pd.DataFrame(data=data, columns=header)

# %% [markdown]
# ### The prefiltered data frame with three columns.

# %%
postcode_df
# Out:
#     postcode           borough          neighbourhood
# 0        M1A      Not assigned           Not assigned
# 1        M2A      Not assigned           Not assigned
# 2        M3A        North York              Parkwoods
# 3        M4A        North York       Victoria Village
# 4        M5A  Downtown Toronto           Harbourfront
# ..       ...               ...                    ...
# 282      M8Z         Etobicoke              Mimico NW
# 283      M8Z         Etobicoke     The Queensway West
# 284      M8Z         Etobicoke  Royal York South West
# 285      M8Z         Etobicoke         South of Bloor
# 286      M9Z      Not assigned           Not assigned
#
# [287 rows x 3 columns]

# %% [markdown]
# Filter out rows where the borough is "Not assigned",
# then if the neighbourhood is "Not assigned", replace it with the borough.

# %%
postcode_df = postcode_df[postcode_df['borough']!='Not assigned']


postcode_df.loc[postcode_df['neighbourhood']=='Not assigned',
                'neighbourhood'] = postcode_df.loc[postcode_df['neighbourhood']=='Not assigned',
                'borough']

# print the dataframe to verify that the change was made
postcode_df.loc[postcode_df['neighbourhood']=='Not assigned']
# Out:
# /home/joshred/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /home/joshred/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Empty DataFrame
# Columns: [postcode, borough, neighbourhood]
# Index: []

# %% [markdown]
# Then split the rows into groups by post code.

# %%
groups = postcode_df[['postcode', 'neighbourhood']].groupby('postcode')

# %%
rejoined = pd.DataFrame([groups['postcode'].transform(lambda x: x), 
              groups['neighbourhood'].transform(lambda x: ','.join(x),)]).T.drop_duplicates()

# %% [markdown]
# It's not clear from the instructions whether we're supposed to keep duplicated boroughs. If we do keep them, our new neighbourhood list field is going to be repeated.

# %%
rejoined.columns=['postcode',"neighbourhood_list"]
rejoined.head(20)
# Out:
#    postcode                                 neighbourhood_list
# 2       M3A                                          Parkwoods
# 3       M4A                                   Victoria Village
# 4       M5A                                       Harbourfront
# 5       M6A                    Lawrence Heights,Lawrence Manor
# 7       M7A                                       Queen's Park
# 9       M9A                                       Queen's Park
# 10      M1B                                      Rouge,Malvern
# 13      M3B                                    Don Mills North
# 14      M4B                     Woodbine Gardens,Parkview Hill
# 16      M5B                            Ryerson,Garden District
# 18      M6B                                          Glencairn
# 21      M9B  Cloverdale,Islington,Martin Grove,Princess Gar...
# 26      M1C               Highland Creek,Rouge Hill,Port Union
# 30      M3C                    Flemingdon Park,Don Mills South
# 32      M4C                                   Woodbine Heights
# 33      M5C                                     St. James Town
# 34      M6C                                 Humewood-Cedarvale
# 37      M9C  Bloordale Gardens,Eringate,Markland Wood,Old B...
# 41      M1E                    Guildwood,Morningside,West Hill
# 46      M4E                                        The Beaches

# %%
postcode_df = pd.merge(postcode_df,rejoined, 'inner', 'postcode').drop('neighbourhood', axis=1)
postcode_df
# Out:
#     postcode           borough  \
# 0        M3A        North York
# 1        M4A        North York
# 2        M5A  Downtown Toronto
# 3        M6A        North York
# 4        M6A        North York
# ..       ...               ...
# 205      M8Z         Etobicoke
# 206      M8Z         Etobicoke
# 207      M8Z         Etobicoke
# 208      M8Z         Etobicoke
# 209      M8Z         Etobicoke
#
#                                     neighbourhood_list
# 0                                            Parkwoods
# 1                                     Victoria Village
# 2                                         Harbourfront
# 3                      Lawrence Heights,Lawrence Manor
# 4                      Lawrence Heights,Lawrence Manor
# ..                                                 ...
# 205  Kingsway Park South West,Mimico NW,The Queensw...
# 206  Kingsway Park South West,Mimico NW,The Queensw...
# 207  Kingsway Park South West,Mimico NW,The Queensw...
# 208  Kingsway Park South West,Mimico NW,The Queensw...
# 209  Kingsway Park South West,Mimico NW,The Queensw...
#
# [210 rows x 3 columns]

# %%
postcode_df.shape
# Out:
# (210, 3)

# %%
#looking ahead, it seems that many rows will be complete duplicates. 
# Let's drop them, and check the shape again.
postcode_df.drop_duplicates(inplace=True)
postcode_df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Start of Question 2
#
# Since the instructions describe geocoder and the google api as unreliable, I'll be using the csv file.

# %%
long_lat = pd.read_csv("http://cocl.us/Geospatial_data")

# %%
long_lat.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ### Merge the data onto our original dataset.
# We should still have 103 rows afterward

# %%
# rename columns to simplify processing
long_lat.columns= ['postcode', 'latitude','longitude']
postcode_df = pd.merge(postcode_df, long_lat, how="left", on='postcode')
postcode_df.head()
# Out:
#   postcode           borough               neighbourhood_list   latitude  \
# 0      M3A        North York                        Parkwoods  43.753259
# 1      M4A        North York                 Victoria Village  43.725882
# 2      M5A  Downtown Toronto                     Harbourfront  43.654260
# 3      M6A        North York  Lawrence Heights,Lawrence Manor  43.718518
# 4      M7A  Downtown Toronto                     Queen's Park  43.662301
#
#    longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
postcode_df.shape
# Out:
# (103, 5)

# %% [markdown]
# # Start of Question 3
# Explore and cluster the neighborhoods in Toronto. You can decide to work with only boroughs that contain the word Toronto and then replicate the same analysis we did to the New York City data. It is up to you.
#
# Just make sure:
#
# to add enough Markdown cells to explain what you decided to do and to report any observations you make.
# to generate maps to visualize your neighborhoods and how they cluster together.
# Once you are happy with your analysis, submit a link to the new Notebook on your Github repository. (3 marks)

# %%
center = [postcode_df['latitude'].median(), postcode_df['longitude'].median()]
toronto_map = folium.Map(location=center,
                         zoom_start=12)

# %%
center = [postcode_df['latitude'].median(), postcode_df['longitude'].median()]
toronto_map = folium.Map(location=center,
                         zoom_start=12)
for ix, postcode, borough, neighborhoods, lat, long in postcode_df.itertuples():
    label = f'{neighborhoods}, {borough}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker([lat, long],
                        radius=3,
                        popup=label,
                        color='blue',
                        fill=True,
                        fill_color='#3186cc',
                        fill_opacity=0.7,
                        parse_html=False ).add_to(toronto_map)
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Setup foursquare Credentials:

# %%
import configparser
config = configparser.ConfigParser()
config.read_file(open('foursquare.env'))
CLIENT_ID = config.get('foursquare','client_id' )
CLIENT_SECRET = config.get('foursquare', 'client_secret')

VERSION = '20180605' # Foursquare API version
radius=500
limit=100
# lat = 43.721577   
# long =-79.51835
# url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, long, radius, limit)
# results = requests.get(url).json()
# results = json_normalize(results['response']['groups'][0]['items'])

# %%
@lru_cache(maxsize=None)
def get_nearby_venues(lat, lng, radius=500, limit=1000, client_id=CLIENT_ID, client_secret=CLIENT_SECRET, version=VERSION):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(client_id, client_secret, version, lat, long, radius, limit)
    results = requests.get(url).json()
    try: 
        results = json_normalize(results['response']['groups'][0]['items'])
        # columns that we want, but may not exist
        expected = pd.DataFrame(None, columns=["venue.name",
                                               "venue.location.postalCode",
                                               "venue.location.lat",
                                               "venue.location.lng", 
                                               "venue.categories"])
        #insert into new dataframe, more or less
        venues = pd.concat([expected, results])[expected.columns]

        venues.columns = ['name', 'ven_postalcode', 'ven_latitude', 'ven_longitude','ven_categories',]
        return venues
    except: 
        return None

# %%
postcode_df.head()
# Out:
#   postcode           borough               neighbourhood_list   latitude  \
# 0      M3A        North York                        Parkwoods  43.753259
# 1      M4A        North York                 Victoria Village  43.725882
# 2      M5A  Downtown Toronto                     Harbourfront  43.654260
# 3      M6A        North York  Lawrence Heights,Lawrence Manor  43.718518
# 4      M7A  Downtown Toronto                     Queen's Park  43.662301
#
#    longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %%
venues = pd.DataFrame(data=None, columns=['merge_key',
                                          'name', 
                                          'ven_postalcode', 
                                          'ven_latitude', 
                                          'ven_longitude',
                                          'ven_categories',])

for ix, lat, lng in list(postcode_df[['latitude', 'longitude']].itertuples()):
    more_venues = get_nearby_venues(lat=lat, lng=lng)
    print(more_venues)
    if more_venues is not None:
        more_venues['merge_key'] = int(ix)
        venues= pd.concat([venues, more_venues])
    

        
venues.shape
# Out:
# /home/joshred/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# /home/joshred/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   del sys.path[0]
#                      name ven_postalcode  ven_latitude  ven_longitude  \
# 0        Pho Com Viet Nam        M3N 2V3     43.756631     -79.518336
# 1               Pizza Hut        M3N 2V3     43.756340     -79.517818
# 2                     KFC        M3N 2V3     43.756600     -79.518100
# 3          The Beer Store        M3N 2V3     43.756094     -79.516239
# 4                  Subway        M3N 2V3     43.756171     -79.518251
# 5             Tim Hortons        M3N 1N1     43.754344     -79.527024
# 6             Tim Hortons        M3N 2K1     43.756128     -79.516266
# 7         Pho Mi Viet Hoa        M3N 2J5     43.751936     -79.515979
# 8          Planet Fitness            NaN     43.757538     -79.519610
# 9     Hwy 400 at Finch W.            NaN     43.754399     -79.526967
# 10  Jian Hing Supermarket        M3N 2K2     43.756673     -79.518444
#
#                                        ven_categories
# 0   [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...
# 1   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 2   [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 3   [{'id': '5370f356bcbc57f1066c94c2', 'name': 'B...
# 4   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 5   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 6   [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 7   [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...
# 8   [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 9   [{'id': '4bf58dd8d48988d1f9931735', 'name': 'R...
# 10  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
#                             name ven_postalcode  ven_latitude  ven_longitude  \
# 0  Oakdale Golf and Country Club            NaN     43.727966     -79.522312
# 1            Commercial Bakeries            NaN     43.727947     -79.522320
# 2              Hwy 401 & Hwy 400            NaN     43.727972     -79.522302
# 3                    auctionmaxx        M9M 2W6     43.727101     -79.525173
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d1e6941735', 'name': 'G...
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 2  [{'id': '52f2ab2ebcbc57f1066b8b4c', 'name': 'I...
# 3  [{'id': '52dea92d3cf9994f4e043dbb', 'name': 'D...
#                          name ven_postalcode  ven_latitude  ven_longitude  \
# 0          Trattoria Leonardo            NaN     43.652893     -79.525300
# 1     Montgomery's Inn Museum            NaN     43.651831     -79.525597
# 2  Kingsway Offleash Dig Park            NaN     43.651777     -79.517483
# 3                     Lenny's            NaN     43.652753     -79.525515
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 1  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...
# 2  [{'id': '4bf58dd8d48988d1e5941735', 'name': 'D...
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
#                             name ven_postalcode  ven_latitude  ven_longitude  \
# 0  The Davey Tree Expert Company        M3L 1G9     43.719333     -79.519042
# 1                    Fiera Foods            NaN     43.718946     -79.525921
# 2                  Country Style            NaN     43.718969     -79.515416
# 3         Pelmo Community Centre            NaN     43.714419     -79.519893
#
#                                       ven_categories
# 0  [{'id': '5454144b498ec1f095bff2f2', 'name': 'C...
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 3  [{'id': '4d4b7105d754a06377d81259', 'name': 'O...
#                           name ven_postalcode  ven_latitude  ven_longitude  \
# 0                   COBS Bread        M9A 3T7     43.664940     -79.520485
# 1           Shoppers Drug Mart        M9A 3T7     43.661721     -79.518881
# 2                    Bulk Barn            NaN     43.660939     -79.517773
# 3                         LCBO        M9A 3T6     43.661298     -79.518150
# 4                      Loblaws        M9A 3T7     43.661721     -79.518881
# 5   Humbertown Shopping Centre        M9A 3T7     43.661797     -79.516861
# 6          Black's Photography        M9A 3T7     43.661490     -79.519317
# 7       Humbertown Village Spa        M9A 3T7     43.661428     -79.519289
# 8               Baskin-Robbins            M9A     43.661654     -79.519190
# 9            Alex Farm Produce            NaN     43.661528     -79.518899
# 10                     Daisaky            NaN     43.662380     -79.519673
# 11      Humbertown Convenience            NaN     43.664929     -79.520481
# 12                  Second Cup            NaN     43.662273     -79.519234
# 13          Humber Valley Rink            NaN     43.664826     -79.524873
# 14          Humber Valley Park            NaN     43.664825     -79.524999
# 15              TTC Stop #6972            NaN     43.666139     -79.519814
#
#                                        ven_categories
# 0   [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 1   [{'id': '4bf58dd8d48988d10f951735', 'name': 'P...
# 2   [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...
# 3   [{'id': '4bf58dd8d48988d186941735', 'name': 'L...
# 4   [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 5   [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...
# 6   [{'id': '4eb1bdf03b7b55596b4a7491', 'name': 'C...
# 7   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 8   [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...
# 9   [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...
# 10  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# 11  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 12  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 13  [{'id': '4bf58dd8d48988d168941735', 'name': 'S...
# 14  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 15  [{'id': '52f2ab2ebcbc57f1066b8b4f', 'name': 'B...
#                      name ven_postalcode  ven_latitude  ven_longitude  \
# 0              COBS Bread        M9A 3T7     43.664940     -79.520485
# 1          TTC Stop #6972            NaN     43.666139     -79.519814
# 2  Humbertown Convenience            NaN     43.664929     -79.520481
# 3      Humber Valley Rink            NaN     43.664826     -79.524873
# 4          Edgehill House            NaN     43.670762     -79.516879
# 5      Humber Valley Park            NaN     43.664825     -79.524999
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 1  [{'id': '52f2ab2ebcbc57f1066b8b4f', 'name': 'B...
# 2  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 3  [{'id': '4bf58dd8d48988d168941735', 'name': 'S...
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 5  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
#                    name ven_postalcode  ven_latitude  ven_longitude  \
# 0          St. Joseph's            NaN     43.804703     -79.523681
# 1          Chair Source        L4K 5Y3     43.803938     -79.525727
# 2  North Toronto Paints        L4K 4L7     43.804160     -79.525980
# 3           Sarana Tile        L4K 5P2     43.806868     -79.527093
#
#                                       ven_categories
# 0  [{'id': '52f2ab2ebcbc57f1066b8b28', 'name': 'P...
# 1  [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...
# 2  [{'id': '5454144b498ec1f095bff2f2', 'name': 'C...
# 3  [{'id': '4bf58dd8d48988d1f8941735', 'name': 'F...
#                         name ven_postalcode  ven_latitude  ven_longitude  \
# 0            Commisso Bakery        M3N 1H7     43.748678     -79.517262
# 1            Eddystone Meats        M3N 1H8     43.747597     -79.521590
# 2             Fennimore Park            NaN     43.745398     -79.522283
# 3  Auto Collision Centre Ltd            NaN     43.748722     -79.518240
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d1dc931735', 'name': 'T...
# 1  [{'id': '4bf58dd8d48988d1f9941735', 'name': 'F...
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 3  [{'id': '52f2ab2ebcbc57f1066b8b44', 'name': 'A...
#                         name ven_postalcode  ven_latitude  ven_longitude  \
# 0                   Elm Park            NaN     43.706139     -79.515869
# 1  Olympic convenience store            NaN     43.704486     -79.515789
# 2                   Eggsmart            NaN     43.702270     -79.523103
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 1  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 2  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...
#                      name ven_postalcode  ven_latitude  ven_longitude  \
# 0               Bulk Barn            NaN     43.660939     -79.517773
# 1  Humbertown Village Spa        M9A 3T7     43.661428     -79.519289
# 2     Black's Photography        M9A 3T7     43.661490     -79.519317
#
#                                       ven_categories
# 0  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...
# 1  [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 2  [{'id': '4eb1bdf03b7b55596b4a7491', 'name': 'C...
#                                              name ven_postalcode  \
# 0                          Wallace C. Swanek Park            NaN
# 1                                    Grattan Park            NaN
# 2                                   Chicken Place            NaN
# 3  Maple Leafs Movers North York : Moving Company        M9N 2P3
# 4                    Level 100 Sports Productions        M9N 2J7
#
#    ven_latitude  ven_longitude  \
# 0     43.708896     -79.522648
# 1     43.706222     -79.521705
# 2     43.711381     -79.516808
# 3     43.712945     -79.523249
# 4     43.707935     -79.526253
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 2  [{'id': '4bf58dd8d48988d1c7941735', 'name': 'S...
# 3  [{'id': '4f2a23984b9023bd5841ed2c', 'name': 'M...
# 4  [{'id': '52e81612bcbc57f1066b7a2e', 'name': 'S...
#                       name ven_postalcode  ven_latitude  ven_longitude  \
# 0       Trattoria Leonardo            NaN     43.652893     -79.525300
# 1  Montgomery's Inn Museum            NaN     43.651831     -79.525597
# 2          Donnybrook Park            NaN     43.653322     -79.520248
# 3               Second Cup        M9A 1B4     43.650432     -79.527168
# 4  Montgomery Dry Cleaners            NaN     43.652676     -79.525246
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 1  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 4  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...
#                          name ven_postalcode  ven_latitude  ven_longitude  \
# 0  Highway 407 Subway Station            NaN     43.782977     -79.523592
# 1                     AB Limo        L4K 1A3     43.788074     -79.522240
# 2                       Noble        L4K 1A7     43.781625     -79.517622
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...
# 1  [{'id': '52f2ab2ebcbc57f1066b8b44', 'name': 'A...
# 2  [{'id': '4bf58dd8d48988d112951735', 'name': 'H...
#                             name ven_postalcode  ven_latitude  ven_longitude  \
# 0  Oakdale Golf and Country Club            NaN     43.727966     -79.522312
# 1            Commercial Bakeries            NaN     43.727947     -79.522320
# 2              Hwy 401 & Hwy 400            NaN     43.727972     -79.522302
# 3                    auctionmaxx        M9M 2W6     43.727101     -79.525173
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d1e6941735', 'name': 'G...
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 2  [{'id': '52f2ab2ebcbc57f1066b8b4c', 'name': 'I...
# 3  [{'id': '52dea92d3cf9994f4e043dbb', 'name': 'D...
#                             name ven_postalcode  ven_latitude  ven_longitude  \
# 0             Weston Lions Arena            NaN     43.698707     -79.518548
# 1                   Petro-Canada        M9P 2T5     43.696091     -79.520962
# 2                    Parma Pizza        M9P 2T5     43.695518     -79.520420
# 3  Starfish Caribbean Market Ltd        M9N 1V6     43.698946     -79.518592
# 4                West Lions Park        M9N 1G4     43.698466     -79.516879
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d168941735', 'name': 'S...
# 1  [{'id': '4bf58dd8d48988d113951735', 'name': 'G...
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 3  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 4  [{'id': '4cce455aebf7b749d5e191f5', 'name': 'S...
#                       name ven_postalcode  ven_latitude  ven_longitude  \
# 0       Trattoria Leonardo            NaN     43.652893     -79.525300
# 1  Montgomery's Inn Museum            NaN     43.651831     -79.525597
# 2          Donnybrook Park            NaN     43.653322     -79.520248
# 3  Montgomery Dry Cleaners            NaN     43.652676     -79.525246
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 1  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 3  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...
#                    name ven_postalcode  ven_latitude  ven_longitude  \
# 0          Petro-Canada        M9P 2T5     43.696091     -79.520962
# 1           Parma Pizza        M9P 2T5     43.695518     -79.520420
# 2  Douglas B. Ford Park            NaN     43.691310     -79.516742
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d113951735', 'name': 'G...
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
#                                   name ven_postalcode  ven_latitude  \
# 0   Gourmet Bakery (Islington Station)            NaN     43.644919
# 1                            Starbucks        M8X 2X3     43.645425
# 2                               Gojima        M8X 1E9     43.645094
# 3                               Sobeys        M8X 2X9     43.645726
# 4                           Lemongrass            NaN     43.645010
# 5                       The Beer Store        M8X 1G4     43.644123
# 6                                  A&W        M8X 1G2     43.645096
# 7                                  A&W        M8X 2X4     43.645360
# 8                           Second Cup        M8X 2W8     43.645331
# 9                         Thai Express        M8X 2X3     43.645427
# 10                              Subway            NaN     43.645014
# 11                         Tim Hortons        M8Z 5B5     43.645278
# 12                       Mitzie's Jerk        M8X 1E9     43.645215
# 13                    GoodLife Fitness        M8X 2X2     43.645540
# 14                         Pizza Pizza        M8X 1G2     43.644959
# 15                            Orwell's        M8X 1G2     43.644885
# 16                     Squire & Firkin        M8X 1E9     43.645231
# 17                             Freshii        M8X 2X2     43.645411
# 18                       Sushi Express            NaN     43.645433
#
#     ven_longitude                                     ven_categories
# 0      -79.524711  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 1      -79.522439  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 2      -79.521672  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# 3      -79.521369  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 4      -79.522379  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 5      -79.525614  [{'id': '5370f356bcbc57f1066c94c2', 'name': 'B...
# 6      -79.522514  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 7      -79.521563  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 8      -79.522753  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 9      -79.522446  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 10     -79.522166  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 11     -79.522363  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 12     -79.521412  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...
# 13     -79.522255  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 14     -79.522468  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 15     -79.523126  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 16     -79.521246  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 17     -79.522638  [{'id': '4c2cd86ed066bed06c3c5209', 'name': 'G...
# 18     -79.525575  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...
#                name ven_postalcode  ven_latitude  ven_longitude  \
# 0      Petro-Canada        M3N 2L2     43.766586     -79.519870
# 1            Rexall        M3N 2L3     43.766590     -79.519852
# 2  Basketball Court            NaN     43.766837     -79.522100
# 3              LCBO        M3N 3A1     43.759257     -79.519454
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d113951735', 'name': 'G...
# 1  [{'id': '4bf58dd8d48988d10f951735', 'name': 'P...
# 2  [{'id': '4bf58dd8d48988d1e1941735', 'name': 'B...
# 3  [{'id': '4bf58dd8d48988d186941735', 'name': 'L...
#                     name ven_postalcode  ven_latitude  ven_longitude  \
# 0  TTC Bus 73 Royal York            NaN     43.677246     -79.519630
# 1    Pasta International            NaN     43.672703     -79.519223
# 2        Allanhurst Park            NaN     43.678968     -79.525004
# 3          A Dog's Haven        M9A 4P5     43.672946     -79.517926
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d12b951735', 'name': 'B...
# 1  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...
# 2  [{'id': '4bf58dd8d48988d1e7941735', 'name': 'P...
# 3  [{'id': '4bf58dd8d48988d1e5941735', 'name': 'D...
#                                   name ven_postalcode  ven_latitude  \
# 0   Gourmet Bakery (Islington Station)            NaN     43.644919
# 1                            Starbucks        M8X 2X3     43.645425
# 2                               Sobeys        M8X 2X9     43.645726
# 3                               Gojima        M8X 1E9     43.645094
# 4                           Lemongrass            NaN     43.645010
# 5                       The Beer Store        M8X 1G4     43.644123
# 6                                  A&W        M8X 1G2     43.645096
# 7                                  A&W        M8X 2X4     43.645360
# 8                           Second Cup        M8X 2W8     43.645331
# 9                         Thai Express        M8X 2X3     43.645427
# 10                              Subway            NaN     43.645014
# 11                         Tim Hortons        M8Z 5B5     43.645278
# 12                    GoodLife Fitness        M8X 2X2     43.645540
# 13                       Mitzie's Jerk        M8X 1E9     43.645215
# 14                         Pizza Pizza        M8X 1G2     43.644959
# 15                            Orwell's        M8X 1G2     43.644885
# 16                     Squire & Firkin        M8X 1E9     43.645231
# 17                             Freshii        M8X 2X2     43.645411
# 18                       Sushi Express            NaN     43.645433
# 19                 Mabelle Convenience            NaN     43.646498
#
#     ven_longitude                                     ven_categories
# 0      -79.524711  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 1      -79.522439  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 2      -79.521369  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 3      -79.521672  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# 4      -79.522379  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 5      -79.525614  [{'id': '5370f356bcbc57f1066c94c2', 'name': 'B...
# 6      -79.522514  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 7      -79.521563  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 8      -79.522753  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 9      -79.522446  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 10     -79.522166  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 11     -79.522363  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 12     -79.522255  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 13     -79.521412  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...
# 14     -79.522468  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 15     -79.523126  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 16     -79.521246  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 17     -79.522638  [{'id': '4c2cd86ed066bed06c3c5209', 'name': 'G...
# 18     -79.525575  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...
# 19     -79.526701  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
#                     name ven_postalcode  ven_latitude  ven_longitude  \
# 0          LaRose Bakery            NaN     43.686835     -79.524436
# 1            Pizza Pizza        M9P 1B2     43.685256     -79.523582
# 2  Moxie's Classic Grill            NaN     43.686870     -79.524454
# 3             Mac's Milk            NaN     43.685572     -79.523698
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 1  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...
# 3  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
#                           name ven_postalcode  ven_latitude  ven_longitude  \
# 0  Black Creek Pioneer Village        M3J 3P1     43.773393     -79.516991
# 1          Tri Star Restaurant        M3N 2L2     43.769336     -79.520250
# 2                 Petro-Canada        M3N 2L2     43.766586     -79.519870
# 3    John Booth Memorial Arena            NaN     43.769549     -79.523248
#
#                                       ven_categories
# 0  [{'id': '4deefb944765f83613cdba6e', 'name': 'H...
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...
# 2  [{'id': '4bf58dd8d48988d113951735', 'name': 'G...
# 3  [{'id': '4bf58dd8d48988d168941735', 'name': 'S...
#                                              name ven_postalcode  \
# 0                                   Chicken Place            NaN
# 1  Maple Leafs Movers North York : Moving Company        M9N 2P3
#
#    ven_latitude  ven_longitude  \
# 0     43.711381     -79.516808
# 1     43.712945     -79.523249
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d1c7941735', 'name': 'S...
# 1  [{'id': '4f2a23984b9023bd5841ed2c', 'name': 'M...
#                      name ven_postalcode  ven_latitude  ven_longitude  \
# 0               Bulk Barn            NaN     43.660939     -79.517773
# 1      Shoppers Drug Mart        M9A 3T7     43.661721     -79.518881
# 2                    LCBO        M9A 3T6     43.661298     -79.518150
# 3                 Loblaws        M9A 3T7     43.661721     -79.518881
# 4  Humbertown Village Spa        M9A 3T7     43.661428     -79.519289
# 5     Black's Photography        M9A 3T7     43.661490     -79.519317
# 6       Alex Farm Produce            NaN     43.661528     -79.518899
# 7          Baskin-Robbins            M9A     43.661654     -79.519190
#
#                                       ven_categories
# 0  [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...
# 1  [{'id': '4bf58dd8d48988d10f951735', 'name': 'P...
# 2  [{'id': '4bf58dd8d48988d186941735', 'name': 'L...
# 3  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 4  [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 5  [{'id': '4eb1bdf03b7b55596b4a7491', 'name': 'C...
# 6  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...
# 7  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...
#              name ven_postalcode  ven_latitude  ven_longitude  \
# 0      McDonald's            NaN     43.671092     -79.526651
# 1  Edgehill House            NaN     43.670762     -79.516879
# 2  TTC Stop #6972            NaN     43.666139     -79.519814
# 3   A Dog's Haven        M9A 4P5     43.672946     -79.517926
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 1  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 2  [{'id': '52f2ab2ebcbc57f1066b8b4f', 'name': 'B...
# 3  [{'id': '4bf58dd8d48988d1e5941735', 'name': 'D...
#                            name ven_postalcode  ven_latitude  ven_longitude  \
# 0   Black Creek Pioneer Village        M3J 3P1     43.773393     -79.516991
# 1                     Cuscatlan        M3H 5T8     43.774848     -79.526254
# 2        Black Creek Restaurant            NaN     43.775301     -79.518268
# 3  Black Creek Historic Brewery        M3J 2P3     43.775122     -79.516833
# 4           Tri Star Restaurant        M3N 2L2     43.769336     -79.520250
# 5     John Booth Memorial Arena            NaN     43.769549     -79.523248
# 6                Com Pho The Ky            NaN     43.774770     -79.526064
#
#                                       ven_categories
# 0  [{'id': '4deefb944765f83613cdba6e', 'name': 'H...
# 1  [{'id': '4bf58dd8d48988d1be941735', 'name': 'L...
# 2  [{'id': '4bf58dd8d48988d155941735', 'name': 'G...
# 3  [{'id': '50327c8591d4c4b30a586d5d', 'name': 'B...
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...
# 5  [{'id': '4bf58dd8d48988d168941735', 'name': 'S...
# 6  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...
#                    name ven_postalcode  ven_latitude  ven_longitude  \
# 0          St. Joseph's            NaN     43.804703     -79.523681
# 1  North Toronto Paints        L4K 4L7     43.804160     -79.525980
#
#                                       ven_categories
# 0  [{'id': '52f2ab2ebcbc57f1066b8b28', 'name': 'P...
# 1  [{'id': '5454144b498ec1f095bff2f2', 'name': 'C...
#                          name ven_postalcode  ven_latitude  ven_longitude  \
# 0            Pho Com Viet Nam        M3N 2V3     43.756631     -79.518336
# 1          Shoppers Drug Mart        M3N 2K1     43.756147     -79.515843
# 2                   Pizza Hut        M3N 2V3     43.756340     -79.517818
# 3                         KFC        M3N 2V3     43.756600     -79.518100
# 4              The Beer Store        M3N 2V3     43.756094     -79.516239
# 5                   No Frills        M3N 3A1     43.758178     -79.519680
# 6   Popeyes Louisiana Kitchen        M3N 2K1     43.756604     -79.516047
# 7                      Subway        M3N 2V3     43.756171     -79.518251
# 8                Petro-Canada        M3N 2Z2     43.757187     -79.517778
# 9                 Pizza Pizza        M3N 2H1     43.756186     -79.515460
# 10                Tim Hortons        M3N 1N1     43.754344     -79.527024
# 11                Tim Hortons        M3N 2K1     43.756128     -79.516266
# 12             Planet Fitness            NaN     43.757538     -79.519610
# 13                  Dollarama        M3N 3A1     43.758177     -79.519679
# 14      Jian Hing Supermarket        M3N 2K2     43.756673     -79.518444
# 15                Living Well        M3N 2V2     43.756461     -79.515989
# 16        Hwy 400 at Finch W.            NaN     43.754399     -79.526967
# 17            Pho Mi Viet Hoa        M3N 2J5     43.751936     -79.515979
# 18              Yorkgate Mall            NaN     43.758664     -79.519641
#
#                                        ven_categories
# 0   [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...
# 1   [{'id': '4bf58dd8d48988d10f951735', 'name': 'P...
# 2   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 3   [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 4   [{'id': '5370f356bcbc57f1066c94c2', 'name': 'B...
# 5   [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 6   [{'id': '4d4ae6fc7a7b7dea34424761', 'name': 'F...
# 7   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 8   [{'id': '4bf58dd8d48988d113951735', 'name': 'G...
# 9   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 10  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 11  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 12  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 13  [{'id': '52dea92d3cf9994f4e043dbb', 'name': 'D...
# 14  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 15  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...
# 16  [{'id': '4bf58dd8d48988d1f9931735', 'name': 'R...
# 17  [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...
# 18  [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...
#                         name ven_postalcode  ven_latitude  ven_longitude  \
# 0         Shoppers Drug Mart        M9N 1X2     43.701264     -79.519705
# 1                   Eggsmart            NaN     43.702270     -79.523103
# 2                   Elm Park            NaN     43.706139     -79.515869
# 3  Olympic convenience store            NaN     43.704486     -79.515789
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d10f951735', 'name': 'P...
# 1  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 3  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
#                       name ven_postalcode  ven_latitude  ven_longitude  \
# 0       Trattoria Leonardo            NaN     43.652893     -79.525300
# 1  Montgomery's Inn Museum            NaN     43.651831     -79.525597
# 2          Donnybrook Park            NaN     43.653322     -79.520248
# 3               Second Cup        M9A 1B4     43.650432     -79.527168
# 4  Montgomery Dry Cleaners            NaN     43.652676     -79.525246
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 1  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 4  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...
#                      name ven_postalcode  ven_latitude  ven_longitude  \
# 0              COBS Bread        M9A 3T7     43.664940     -79.520485
# 1          TTC Stop #6972            NaN     43.666139     -79.519814
# 2          Edgehill House            NaN     43.670762     -79.516879
# 3  Humbertown Convenience            NaN     43.664929     -79.520481
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 1  [{'id': '52f2ab2ebcbc57f1066b8b4f', 'name': 'B...
# 2  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 3  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
#                         name ven_postalcode  ven_latitude  ven_longitude  \
# 0             Fennimore Park            NaN     43.745398     -79.522283
# 1            Eddystone Meats        M3N 1H8     43.747597     -79.521590
# 2  Auto Collision Centre Ltd            NaN     43.748722     -79.518240
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 1  [{'id': '4bf58dd8d48988d1f9941735', 'name': 'F...
# 2  [{'id': '52f2ab2ebcbc57f1066b8b44', 'name': 'A...
#                      name ven_postalcode  ven_latitude  ven_longitude  \
# 0  Black Creek Restaurant            NaN     43.775301     -79.518268
# 1                   Noble        L4K 1A7     43.781625     -79.517622
# 2             Tasty Pizza        M3N 2X7     43.774121     -79.521870
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d155941735', 'name': 'G...
# 1  [{'id': '4bf58dd8d48988d112951735', 'name': 'H...
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
#                          name ven_postalcode  ven_latitude  ven_longitude  \
# 0                Petro-Canada        M3N 2L2     43.766586     -79.519870
# 1         Tri Star Restaurant        M3N 2L2     43.769336     -79.520250
# 2   John Booth Memorial Arena            NaN     43.769549     -79.523248
# 3  Driftwood community centre            M3N     43.765680     -79.519706
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d113951735', 'name': 'G...
# 1  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...
# 2  [{'id': '4bf58dd8d48988d168941735', 'name': 'S...
# 3  [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...
#                     name ven_postalcode  ven_latitude  ven_longitude  \
# 0            Plant World        M9A 4M2     43.683627     -79.522305
# 1          LaRose Bakery            NaN     43.686835     -79.524436
# 2            Pizza Pizza        M9P 1B2     43.685256     -79.523582
# 3             Mac's Milk            NaN     43.685572     -79.523698
# 4  Moxie's Classic Grill            NaN     43.686870     -79.524454
# 5           LaRose Plaza            NaN     43.685969     -79.526411
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d112951735', 'name': 'H...
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 2  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 3  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...
# 5  [{'id': '4bf58dd8d48988d164941735', 'name': 'P...
#                           name ven_postalcode  ven_latitude  ven_longitude  \
# 0  Power Yoga Canada Etobicoke            NaN     43.636592     -79.520312
# 1                       Gojima        M8X 1E9     43.645094     -79.521672
# 2                   Lemongrass            NaN     43.645010     -79.522379
# 3                          A&W        M8X 1G2     43.645096     -79.522514
# 4                       Subway            NaN     43.645014     -79.522166
# 5                Mitzie's Jerk        M8X 1E9     43.645215     -79.521412
# 6                  Pizza Pizza        M8X 1G2     43.644959     -79.522468
# 7                     Orwell's        M8X 1G2     43.644885     -79.523126
# 8               Tom Riley Park            NaN     43.638972     -79.525564
# 9              Squire & Firkin        M8X 1E9     43.645231     -79.521246
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...
# 1  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# 2  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 3  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 4  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 5  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...
# 6  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 7  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 8  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 9  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
#                                   name ven_postalcode  ven_latitude  \
# 0                            Starbucks        M8X 2X3     43.645425
# 1   Gourmet Bakery (Islington Station)            NaN     43.644919
# 2                               Sobeys        M8X 2X9     43.645726
# 3                               Gojima        M8X 1E9     43.645094
# 4                           Lemongrass            NaN     43.645010
# 5                                  A&W        M8X 1G2     43.645096
# 6                                  A&W        M8X 2X4     43.645360
# 7                         Thai Express        M8X 2X3     43.645427
# 8                           Second Cup        M8X 2W8     43.645331
# 9                               Subway            NaN     43.645014
# 10                    GoodLife Fitness        M8X 2X2     43.645540
# 11                         Tim Hortons        M8Z 5B5     43.645278
# 12                       Mitzie's Jerk        M8X 1E9     43.645215
# 13                         Pizza Pizza        M8X 1G2     43.644959
# 14                            Orwell's        M8X 1G2     43.644885
# 15                     Squire & Firkin        M8X 1E9     43.645231
# 16                             Freshii        M8X 2X2     43.645411
# 17                       Sushi Express            NaN     43.645433
# 18                 Mabelle Convenience            NaN     43.646498
# 19               Enterprise Rent-A-Car        M8X 1Z4     43.646860
#
#     ven_longitude                                     ven_categories
# 0      -79.522439  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 1      -79.524711  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 2      -79.521369  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 3      -79.521672  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# 4      -79.522379  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 5      -79.522514  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 6      -79.521563  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 7      -79.522446  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 8      -79.522753  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 9      -79.522166  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 10     -79.522255  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 11     -79.522363  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 12     -79.521412  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...
# 13     -79.522468  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 14     -79.523126  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 15     -79.521246  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 16     -79.522638  [{'id': '4c2cd86ed066bed06c3c5209', 'name': 'G...
# 17     -79.525575  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...
# 18     -79.526701  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 19     -79.515110  [{'id': '4bf58dd8d48988d1ef941735', 'name': 'R...
#                             name ven_postalcode  ven_latitude  ven_longitude  \
# 0  Oakdale Golf and Country Club            NaN     43.727966     -79.522312
# 1              Hwy 401 & Hwy 400            NaN     43.727972     -79.522302
# 2            Commercial Bakeries            NaN     43.727947     -79.522320
# 3                    auctionmaxx        M9M 2W6     43.727101     -79.525173
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d1e6941735', 'name': 'G...
# 1  [{'id': '52f2ab2ebcbc57f1066b8b4c', 'name': 'I...
# 2  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 3  [{'id': '52dea92d3cf9994f4e043dbb', 'name': 'D...
#                                   name ven_postalcode  ven_latitude  \
# 0  Doublerinks Arena - Vaughan Iceplex            NaN     43.789973
# 1                   Pro Hockey Network            NaN     43.790301
# 2               Highway 407 GO Station        L4K 1A7     43.783255
# 3           Highway 407 Subway Station            NaN     43.782977
#
#    ven_longitude                                     ven_categories
# 0     -79.521270  [{'id': '4bf58dd8d48988d168941735', 'name': 'S...
# 1     -79.521062  [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...
# 2     -79.523846  [{'id': '4bf58dd8d48988d1fe931735', 'name': 'B...
# 3     -79.523592  [{'id': '4bf58dd8d48988d1fd931735', 'name': 'M...
#                                  name ven_postalcode  ven_latitude  \
# 0  Toronto air duct cleaning services        M3N 1B3     43.739496
# 1                         Wok of Fame            NaN     43.740249
#
#    ven_longitude                                     ven_categories
# 0     -79.522492  [{'id': '52f2ab2ebcbc57f1066b8b1d', 'name': 'D...
# 1     -79.518762  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...
#                     name ven_postalcode  ven_latitude  ven_longitude  \
# 0            Plant World        M9A 4M2     43.683627     -79.522305
# 1        Buttonwood Park            NaN     43.681281     -79.519472
# 2  TTC Bus 73 Royal York            NaN     43.677246     -79.519630
# 3        Allanhurst Park            NaN     43.678968     -79.525004
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d112951735', 'name': 'H...
# 1  [{'id': '4bf58dd8d48988d1e7941735', 'name': 'P...
# 2  [{'id': '4bf58dd8d48988d12b951735', 'name': 'B...
# 3  [{'id': '4bf58dd8d48988d1e7941735', 'name': 'P...
#                                   name ven_postalcode  ven_latitude  \
# 0                            Starbucks        M8X 2X3     43.645425
# 1   Gourmet Bakery (Islington Station)            NaN     43.644919
# 2                               Sobeys        M8X 2X9     43.645726
# 3                               Gojima        M8X 1E9     43.645094
# 4                           Lemongrass            NaN     43.645010
# 5                                  A&W        M8X 1G2     43.645096
# 6                                  A&W        M8X 2X4     43.645360
# 7                         Thai Express        M8X 2X3     43.645427
# 8                           Second Cup        M8X 2W8     43.645331
# 9                               Subway            NaN     43.645014
# 10                    GoodLife Fitness        M8X 2X2     43.645540
# 11                         Tim Hortons        M8Z 5B5     43.645278
# 12                       Mitzie's Jerk        M8X 1E9     43.645215
# 13                         Pizza Pizza        M8X 1G2     43.644959
# 14                     Squire & Firkin        M8X 1E9     43.645231
# 15                            Orwell's        M8X 1G2     43.644885
# 16                             Freshii        M8X 2X2     43.645411
# 17                       Sushi Express            NaN     43.645433
# 18                 Mabelle Convenience            NaN     43.646498
# 19               Enterprise Rent-A-Car        M8X 1Z4     43.646860
#
#     ven_longitude                                     ven_categories
# 0      -79.522439  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 1      -79.524711  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 2      -79.521369  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 3      -79.521672  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# 4      -79.522379  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 5      -79.522514  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 6      -79.521563  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 7      -79.522446  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 8      -79.522753  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 9      -79.522166  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 10     -79.522255  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 11     -79.522363  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 12     -79.521412  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...
# 13     -79.522468  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 14     -79.521246  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 15     -79.523126  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 16     -79.522638  [{'id': '4c2cd86ed066bed06c3c5209', 'name': 'G...
# 17     -79.525575  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...
# 18     -79.526701  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 19     -79.515110  [{'id': '4bf58dd8d48988d1ef941735', 'name': 'R...
#                                 name ven_postalcode  ven_latitude  \
# 0        Power Yoga Canada Etobicoke            NaN     43.636592
# 1                        Tim Hortons        M8Z 4R9     43.635973
# 2                    TD Canada Trust        M8Z 4R6     43.633786
# 3                Rocco's Plum Tomato            NaN     43.634898
# 4                         Second Cup        M8Z 4R6     43.634262
# 5                Rainbow Convenience            NaN     43.635901
# 6                      Fresh & Tasty            M8Z     43.635899
# 7                     Tom Riley Park            NaN     43.638972
# 8  Armstrong & Nelson Eavestroughing        M8Z 2W1     43.637847
#
#    ven_longitude                                     ven_categories
# 0     -79.520312  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...
# 1     -79.520597  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 2     -79.519649  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...
# 3     -79.519951  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 4     -79.519854  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...
# 5     -79.520464  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 6     -79.520534  [{'id': '4bf58dd8d48988d146941735', 'name': 'D...
# 7     -79.525564  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 8     -79.515342  [{'id': '545419b1498ea6ccd0202f58', 'name': 'H...
#                      name ven_postalcode  ven_latitude  ven_longitude  \
# 0  Wallace C. Swanek Park            NaN     43.708896     -79.522648
# 1  Pelmo Community Centre            NaN     43.714419     -79.519893
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 1  [{'id': '4d4b7105d754a06377d81259', 'name': 'O...
#                          name ven_postalcode  ven_latitude  ven_longitude  \
# 0                   No Frills        M3N 3A1     43.758178     -79.519680
# 1            Pho Com Viet Nam        M3N 2V3     43.756631     -79.518336
# 2                   Pizza Hut        M3N 2V3     43.756340     -79.517818
# 3                         KFC        M3N 2V3     43.756600     -79.518100
# 4          Shoppers Drug Mart        M3N 2K1     43.756147     -79.515843
# 5                Petro-Canada        M3N 2Z2     43.757187     -79.517778
# 6   Popeyes Louisiana Kitchen        M3N 2K1     43.756604     -79.516047
# 7              The Beer Store        M3N 2V3     43.756094     -79.516239
# 8                      Subway        M3N 2V3     43.756171     -79.518251
# 9                 Pizza Pizza        M3N 2H1     43.756186     -79.515460
# 10             Planet Fitness            NaN     43.757538     -79.519610
# 11                       LCBO        M3N 3A1     43.759257     -79.519454
# 12                Tim Hortons        M3N 2K1     43.756128     -79.516266
# 13                Living Well        M3N 2V2     43.756461     -79.515989
# 14                  Dollarama        M3N 2V2     43.756770     -79.515084
#
#                                        ven_categories
# 0   [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 1   [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...
# 2   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 3   [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 4   [{'id': '4bf58dd8d48988d10f951735', 'name': 'P...
# 5   [{'id': '4bf58dd8d48988d113951735', 'name': 'G...
# 6   [{'id': '4d4ae6fc7a7b7dea34424761', 'name': 'F...
# 7   [{'id': '5370f356bcbc57f1066c94c2', 'name': 'B...
# 8   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 9   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 10  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...
# 11  [{'id': '4bf58dd8d48988d186941735', 'name': 'L...
# 12  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 13  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...
# 14  [{'id': '52dea92d3cf9994f4e043dbb', 'name': 'D...
#             name ven_postalcode  ven_latitude  ven_longitude  \
# 0    Wok of Fame            NaN     43.740249     -79.518762
# 1  Country Style        M3N 1V9     43.737045     -79.523811
#
# ...
# 14                         Pizza Pizza        M8X 1G2     43.644959
# 15                            Orwell's        M8X 1G2     43.644885
# 16                     Squire & Firkin        M8X 1E9     43.645231
# 17                             Freshii        M8X 2X2     43.645411
# 18                       Sushi Express            NaN     43.645433
# 19                 Mabelle Convenience            NaN     43.646498
# 20               Enterprise Rent-A-Car        M8X 1Z4     43.646860
#
#     ven_longitude                                     ven_categories
# 0      -79.522439  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 1      -79.524711  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 2      -79.521369  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 3      -79.521672  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# 4      -79.522379  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 5      -79.522514  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 6      -79.525614  [{'id': '5370f356bcbc57f1066c94c2', 'name': 'B...
# 7      -79.521563  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 8      -79.522753  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 9      -79.522446  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 10     -79.522166  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 11     -79.522363  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 12     -79.522255  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 13     -79.521412  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...
# 14     -79.522468  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 15     -79.523126  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 16     -79.521246  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 17     -79.522638  [{'id': '4c2cd86ed066bed06c3c5209', 'name': 'G...
# 18     -79.525575  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...
# 19     -79.526701  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 20     -79.515110  [{'id': '4bf58dd8d48988d1ef941735', 'name': 'R...
#                                       name ven_postalcode  ven_latitude  \
# 0  Mastercard Centre For Hockey Excellence        M8V 3L1     43.603126
# 1                          Egglicious Cafe        M8Z 5C9     43.606485
# 2                              Tim Hortons        M8Z 5C9     43.606077
# 3                   The Kingdom Of Awesome            NaN     43.600561
#
#    ven_longitude                                     ven_categories
# 0     -79.519818  [{'id': '4bf58dd8d48988d168941735', 'name': 'S...
# 1     -79.520693  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...
# 2     -79.520600  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 3     -79.525743  [{'id': '4bf58dd8d48988d118941735', 'name': 'D...
#                         name ven_postalcode  ven_latitude  ven_longitude  \
# 0                   Elm Park            NaN     43.706139     -79.515869
# 1  Olympic convenience store            NaN     43.704486     -79.515789
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 1  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
#                       name ven_postalcode  ven_latitude  ven_longitude  \
# 0                 Reptilia        L4K 2N6     43.833522     -79.519677
# 1         Wegz Stadium Bar        L4K 2N6     43.833275     -79.521255
# 2       The Sports Village        L4K 5R1     43.835936     -79.518714
# 3                  Denny's        L4K 0H1     43.834149     -79.520938
# 4             Petro-Canada        L4K 2N6     43.832833     -79.522492
# 5              Planet Play            NaN     43.832397     -79.520003
# 6              Tim Hortons        L4K 0H1     43.834184     -79.520454
# 7    California Sandwiches            NaN     43.834150     -79.521290
# 8         The Archery Game        L4K 2N6     43.833304     -79.519146
# 9        Sanctuary Day Spa            NaN     43.833072     -79.523849
# 10  Musaic School Of Music        L4K 2N6     43.832388     -79.519116
#
#                                        ven_categories
# 0   [{'id': '4bf58dd8d48988d17b941735', 'name': 'Z...
# 1   [{'id': '4bf58dd8d48988d11d941735', 'name': 'S...
# 2   [{'id': '4bf58dd8d48988d168941735', 'name': 'S...
# 3   [{'id': '4bf58dd8d48988d143941735', 'name': 'B...
# 4   [{'id': '4bf58dd8d48988d113951735', 'name': 'G...
# 5   [{'id': '4bf58dd8d48988d182941735', 'name': 'T...
# 6   [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...
# 7   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 8   [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...
# 9   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 10  [{'id': '4f04b10d2fb6e1c99f3db0be', 'name': 'M...
#                      name ven_postalcode  ven_latitude  ven_longitude  \
# 0              COBS Bread        M9A 3T7     43.664940     -79.520485
# 1          TTC Stop #6972            NaN     43.666139     -79.519814
# 2  Humbertown Convenience            NaN     43.664929     -79.520481
# 3          Edgehill House            NaN     43.670762     -79.516879
# 4      Humber Valley Rink            NaN     43.664826     -79.524873
# 5      Humber Valley Park            NaN     43.664825     -79.524999
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 1  [{'id': '52f2ab2ebcbc57f1066b8b4f', 'name': 'B...
# 2  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 3  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 4  [{'id': '4bf58dd8d48988d168941735', 'name': 'S...
# 5  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
#                                   name ven_postalcode  ven_latitude  \
# 0                            Starbucks        M8X 2X3     43.645425
# 1   Gourmet Bakery (Islington Station)            NaN     43.644919
# 2                               Sobeys        M8X 2X9     43.645726
# 3                               Gojima        M8X 1E9     43.645094
# 4                           Lemongrass            NaN     43.645010
# 5                                  A&W        M8X 1G2     43.645096
# 6                                  A&W        M8X 2X4     43.645360
# 7                         Thai Express        M8X 2X3     43.645427
# 8                           Second Cup        M8X 2W8     43.645331
# 9                               Subway            NaN     43.645014
# 10                    GoodLife Fitness        M8X 2X2     43.645540
# 11                         Tim Hortons        M8Z 5B5     43.645278
# 12                       Mitzie's Jerk        M8X 1E9     43.645215
# 13                         Pizza Pizza        M8X 1G2     43.644959
# 14                            Orwell's        M8X 1G2     43.644885
# 15                     Squire & Firkin        M8X 1E9     43.645231
# 16                             Freshii        M8X 2X2     43.645411
# 17                       Sushi Express            NaN     43.645433
#
#     ven_longitude                                     ven_categories
# 0      -79.522439  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 1      -79.524711  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 2      -79.521369  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 3      -79.521672  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# 4      -79.522379  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 5      -79.522514  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 6      -79.521563  [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 7      -79.522446  [{'id': '4bf58dd8d48988d149941735', 'name': 'T...
# 8      -79.522753  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 9      -79.522166  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 10     -79.522255  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 11     -79.522363  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 12     -79.521412  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...
# 13     -79.522468  [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...
# 14     -79.523126  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 15     -79.521246  [{'id': '4bf58dd8d48988d11b941735', 'name': 'P...
# 16     -79.522638  [{'id': '4c2cd86ed066bed06c3c5209', 'name': 'G...
# 17     -79.525575  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...
#                          name ven_postalcode  ven_latitude  ven_longitude  \
# 0          Trattoria Leonardo            NaN     43.652893     -79.525300
# 1     Montgomery's Inn Museum            NaN     43.651831     -79.525597
# 2  Kingsway Offleash Dig Park            NaN     43.651777     -79.517483
# 3                     Lenny's            NaN     43.652753     -79.525515
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 1  [{'id': '4bf58dd8d48988d190941735', 'name': 'H...
# 2  [{'id': '4bf58dd8d48988d1e5941735', 'name': 'D...
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
#                      name ven_postalcode  ven_latitude  ven_longitude  \
# 0              COBS Bread        M9A 3T7     43.664940     -79.520485
# 1      Shoppers Drug Mart        M9A 3T7     43.661721     -79.518881
# 2  Humbertown Convenience            NaN     43.664929     -79.520481
# 3          TTC Stop #6972            NaN     43.666139     -79.519814
# 4      Humber Valley Rink            NaN     43.664826     -79.524873
# 5      Humber Valley Park            NaN     43.664825     -79.524999
# 6                 Loblaws        M9A 3T7     43.661721     -79.518881
# 7                 Daisaky            NaN     43.662380     -79.519673
# 8          Baskin-Robbins            M9A     43.661654     -79.519190
#
#                                       ven_categories
# 0  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 1  [{'id': '4bf58dd8d48988d10f951735', 'name': 'P...
# 2  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 3  [{'id': '52f2ab2ebcbc57f1066b8b4f', 'name': 'B...
# 4  [{'id': '4bf58dd8d48988d168941735', 'name': 'S...
# 5  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 6  [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 7  [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# 8  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...
#                           name ven_postalcode  ven_latitude  ven_longitude  \
# 0                   COBS Bread        M9A 3T7     43.664940     -79.520485
# 1           Shoppers Drug Mart        M9A 3T7     43.661721     -79.518881
# 2                    Bulk Barn            NaN     43.660939     -79.517773
# 3                         LCBO        M9A 3T6     43.661298     -79.518150
# 4                      Loblaws        M9A 3T7     43.661721     -79.518881
# 5   Humbertown Shopping Centre        M9A 3T7     43.661797     -79.516861
# 6          Black's Photography        M9A 3T7     43.661490     -79.519317
# 7       Humbertown Village Spa        M9A 3T7     43.661428     -79.519289
# 8               Baskin-Robbins            M9A     43.661654     -79.519190
# 9                      Daisaky            NaN     43.662380     -79.519673
# 10           Alex Farm Produce            NaN     43.661528     -79.518899
# 11      Humbertown Convenience            NaN     43.664929     -79.520481
# 12          Humber Valley Rink            NaN     43.664826     -79.524873
# 13              TTC Stop #6972            NaN     43.666139     -79.519814
# 14          Humber Valley Park            NaN     43.664825     -79.524999
#
#                                        ven_categories
# 0   [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 1   [{'id': '4bf58dd8d48988d10f951735', 'name': 'P...
# 2   [{'id': '52f2ab2ebcbc57f1066b8b46', 'name': 'S...
# 3   [{'id': '4bf58dd8d48988d186941735', 'name': 'L...
# 4   [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 5   [{'id': '4bf58dd8d48988d1fd941735', 'name': 'S...
# 6   [{'id': '4eb1bdf03b7b55596b4a7491', 'name': 'C...
# 7   [{'id': '4bf58dd8d48988d1ed941735', 'name': 'S...
# 8   [{'id': '4bf58dd8d48988d1c9941735', 'name': 'I...
# 9   [{'id': '4bf58dd8d48988d111941735', 'name': 'J...
# 10  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...
# 11  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 12  [{'id': '4bf58dd8d48988d168941735', 'name': 'S...
# 13  [{'id': '52f2ab2ebcbc57f1066b8b4f', 'name': 'B...
# 14  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
#                                 name ven_postalcode  ven_latitude  \
# 0        Power Yoga Canada Etobicoke            NaN     43.636592
# 1                    TD Canada Trust        M8Z 4R6     43.633786
# 2                        Tim Hortons        M8Z 4R9     43.635973
# 3                Rocco's Plum Tomato            NaN     43.634898
# 4                         Second Cup        M8Z 4R6     43.634262
# 5                Rainbow Convenience            NaN     43.635901
# 6                      Fresh & Tasty            M8Z     43.635899
# 7                     Tom Riley Park            NaN     43.638972
# 8  Armstrong & Nelson Eavestroughing        M8Z 2W1     43.637847
#
#    ven_longitude                                     ven_categories
# 0     -79.520312  [{'id': '4bf58dd8d48988d102941735', 'name': 'Y...
# 1     -79.519649  [{'id': '4bf58dd8d48988d10a951735', 'name': 'B...
# 2     -79.520597  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...
# 3     -79.519951  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 4     -79.519854  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...
# 5     -79.520464  [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 6     -79.520534  [{'id': '4bf58dd8d48988d146941735', 'name': 'D...
# 7     -79.525564  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...
# 8     -79.515342  [{'id': '545419b1498ea6ccd0202f58', 'name': 'H...
#                            name ven_postalcode  ven_latitude  ven_longitude  \
# 0                    Wingporium        M8Z 4P8     43.630275     -79.518169
# 1              South St. Burger        M8Z 6A4     43.631314     -79.518408
# 2                     Dollarama        M8Z 4P8     43.629883     -79.518627
# 3          Artisano Bakery Café        M8Z 6A4     43.631006     -79.518172
# 4                Healthy Planet        M8Z 4P8     43.630214     -79.518495
# 5                      7-Eleven        M8Z 4P8     43.629107     -79.517431
# 6                        Subway        M8Z 6A4     43.631659     -79.519001
# 7                    McDonald's        M8Z 5X5     43.630017     -79.518037
# 8                     No Frills        M8Z 6A4     43.631152     -79.518617
# 9                          RONA        M8Z 4P8     43.629393     -79.518320
# 10   Royal Canadian Legion #210        M8Z 2H1     43.628855     -79.518903
# 11  Islington Florist & Nursery            NaN     43.630156     -79.518718
# 12                Value Village        M8Z 6A4     43.631269     -79.518238
# 13         Kingsway Boxing Club        M8Z 2G6     43.627254     -79.526684
# 14                 Burrito Boyz            NaN     43.626657     -79.526349
#
#                                        ven_categories
# 0   [{'id': '4bf58dd8d48988d14c941735', 'name': 'W...
# 1   [{'id': '4bf58dd8d48988d16c941735', 'name': 'B...
# 2   [{'id': '52dea92d3cf9994f4e043dbb', 'name': 'D...
# 3   [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...
# 4   [{'id': '5744ccdfe4b0c0459246b4cd', 'name': 'S...
# 5   [{'id': '4d954b0ea243a5684a65b473', 'name': 'C...
# 6   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...
# 7   [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...
# 8   [{'id': '4bf58dd8d48988d118951735', 'name': 'G...
# 9   [{'id': '4bf58dd8d48988d112951735', 'name': 'H...
# 10  [{'id': '52e81612bcbc57f1066b7a33', 'name': 'S...
# 11  [{'id': '4bf58dd8d48988d11b951735', 'name': 'F...
# 12  [{'id': '4bf58dd8d48988d101951735', 'name': 'T...
# 13  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...
# 14  [{'id': '4bf58dd8d48988d153941735', 'name': 'B...
# (696, 6)

# %%
venues
# Out:
#    merge_key                         name  \
# 0          0             Pho Com Viet Nam
# 1          0                    Pizza Hut
# 2          0                          KFC
# 3          0               The Beer Store
# 4          0                       Subway
# ..       ...                          ...
# 10       102   Royal Canadian Legion #210
# 11       102  Islington Florist & Nursery
# 12       102                Value Village
# 13       102         Kingsway Boxing Club
# 14       102                 Burrito Boyz
#
#                                        ven_categories  ven_latitude  \
# 0   [{'id': '4bf58dd8d48988d14a941735', 'name': 'V...     43.756631
# 1   [{'id': '4bf58dd8d48988d1ca941735', 'name': 'P...     43.756340
# 2   [{'id': '4bf58dd8d48988d16e941735', 'name': 'F...     43.756600
# 3   [{'id': '5370f356bcbc57f1066c94c2', 'name': 'B...     43.756094
# 4   [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...     43.756171
# ..                                                ...           ...
# 10  [{'id': '52e81612bcbc57f1066b7a33', 'name': 'S...     43.628855
# 11  [{'id': '4bf58dd8d48988d11b951735', 'name': 'F...     43.630156
# 12  [{'id': '4bf58dd8d48988d101951735', 'name': 'T...     43.631269
# 13  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...     43.627254
# 14  [{'id': '4bf58dd8d48988d153941735', 'name': 'B...     43.626657
#
#     ven_longitude ven_postalcode
# 0      -79.518336        M3N 2V3
# 1      -79.517818        M3N 2V3
# 2      -79.518100        M3N 2V3
# 3      -79.516239        M3N 2V3
# 4      -79.518251        M3N 2V3
# ..            ...            ...
# 10     -79.518903        M8Z 2H1
# 11     -79.518718            NaN
# 12     -79.518238        M8Z 6A4
# 13     -79.526684        M8Z 2G6
# 14     -79.526349            NaN
#
# [696 rows x 6 columns]

# %%
 df = pd.merge(postcode_df, venues, left_index=True, right_on='merge_key')
#parse out categories:
df['ven_categories']=df.ven_categories.apply(lambda x: x[0]['shortName'])
df.to_csv('merged_data.csv')

# %%
merged_records = pd.read_csv('merged_data.csv',index_col=0)
merged_records.reset_index(inplace=True)

# %%
merged = pd.merge(merged_records, pd.get_dummies(merged_records["ven_categories"]),left_index=True, right_index=True)

# %%
cols = ['latitude',
 'longitude',
 'Apparel',
 'Athletics & Sports',
 'Auto Garage',
 'Bakery',
 'Bank',
 'Baseball Field',
 'Basketball Court',
 'Beer Store',
 'Breakfast',
 'Brewery',
 'Burgers',
 'Burritos',
 'Bus',
 'Bus Station',
 'Bus Stop',
 'Business Services',
 'Butcher',
 'Café',
 'Camera Store',
 'Caribbean',
 'Chinese',
 'Coffee Shop',
 'Construction',
 'Convenience Store',
 'Deli / Bodega',
 'Diner',
 'Discount Store',
 'Dive Bar',
 'Dog Run',
 'Dry Cleaner',
 'Fast Food',
 'Flower Shop',
 'Food & Drink',
 'Fried Chicken',
 'Furniture / Home',
 'Gas Station',
 'Gastropub',
 'Gluten-free',
 'Golf Course',
 'Grocery Store',
 'Gym',
 'Gym / Fitness',
 'Hardware',
 'Historic Site',
 'History Museum',
 'Home Services',
 'Ice Cream',
 'Indian',
 'Intersection',
 'Italian',
 'Japanese',
 'Latin American',
 'Liquor Store',
 'Locksmith',
 'Mall',
 'Metro',
 'Moving Target',
 'Music School',
 'Nightclub',
 'Nightlife',
 'Outdoors & Recreation',
 'Park',
 'Pharmacy',
 'Pizza',
 'Playground',
 'Plaza',
 'Pool',
 'Print Shop',
 'Pub',
 'Rental Car',
 'Restaurant',
 'Road',
 'Salon / Barbershop',
 'Sandwiches',
 'Skating Rink',
 'Snacks',
 'Soccer Field',
 'Social Club',
 'Spa',
 'Sports Bar',
 'Sports Club',
 'Supermarket',
 'Supplement Shop',
 'Sushi',
 'Tea Room',
 'Thai',
 'Theme Park',
 'Thrift / Vintage',
 'Video Games',
 'Vietnamese',
 'Wings',
 'Yoga Studio',
 'Zoo']

# %%
grouped = merged[cols].groupby(['latitude', 'longitude'])
means = grouped.mean()
means.columns = [c + '_vertical_mean' for c in means.columns]
sums = grouped.sum()
sums['size'] = sums.sum(axis=1)
for column in sums.columns[:-1]:
    sums[column] = sums[column] / sums['size']
sums.columns = [c + '_horizontal_mean' if c != 'size' else c for c in sums.columns] 

scores = pd.merge(sums, means, left_index=True, right_index=True)

# %%
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X=scores)

# %%
from sklearn.cluster import KMeans
kmm = KMeans(n_clusters = 5)
labels = kmm.fit(X).predict(X)

# %%
ix = scores[[]]

# %%
ix['cluster']=labels
ix
# Out:
# /home/joshred/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                       cluster
# latitude  longitude
# 43.602414 -79.543484        1
# 43.605647 -79.501321        1
# 43.628841 -79.520999        4
# 43.628947 -79.394420        4
# 43.636258 -79.498509        1
# ...                       ...
# 43.799525 -79.318389        1
# 43.803762 -79.363452        2
# 43.806686 -79.194353        2
# 43.815252 -79.284577        1
# 43.836125 -79.205636        3
#
# [103 rows x 1 columns]

# %%
labeled = pd.merge(postcode_df, ix, left_on=['latitude','longitude'], right_index=True)

# %%
labeled
# Out:
#     postcode           borough  \
# 0        M3A        North York
# 2        M5A  Downtown Toronto
# 4        M7A  Downtown Toronto
# 5        M9A      Queen's Park
# 8        M4B         East York
# ..       ...               ...
# 91       M4W  Downtown Toronto
# 93       M8W         Etobicoke
# 96       M4X  Downtown Toronto
# 97       M5X  Downtown Toronto
# 100      M7Y      East Toronto
#
#                                     neighbourhood_list   latitude  longitude  \
# 0                                            Parkwoods  43.753259 -79.329656
# 2                                         Harbourfront  43.654260 -79.360636
# 4                                         Queen's Park  43.662301 -79.389494
# 5                                         Queen's Park  43.667856 -79.532242
# 8                       Woodbine Gardens,Parkview Hill  43.706397 -79.309937
# ..                                                 ...        ...        ...
# 91                                            Rosedale  43.679563 -79.377529
# 93                               Alderwood,Long Branch  43.602414 -79.543484
# 96                          Cabbagetown,St. James Town  43.667967 -79.367675
# 97               First Canadian Place,Underground city  43.648429 -79.382280
# 100  Business Reply Mail Processing Centre 969 Eastern  43.662744 -79.321558
#
#      cluster
# 0          1
# 2          1
# 4          1
# 5          1
# 8          1
# ..       ...
# 91         1
# 93         1
# 96         1
# 97         0
# 100        1
#
# [62 rows x 6 columns]

# %%
colors = {0:'red',1:'orange', 2:'yellow',3:'green', 4:'blue' }
for ix, postcode, borough, neighborhoods, lat, long, cluster in labeled.itertuples():
    label = f'{neighborhoods}, {borough}'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker([lat, long],
                        radius=3,
                        popup=label,
                        color=colors[cluster],
                        fill=True,
                        fill_color='#3186cc',
                        fill_opacity=0.7,
                        parse_html=False ).add_to(toronto_map)
toronto_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
